# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('adult.data')

# %%
data.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (32560, 15)

# %%
column_names = ['age', 'workclass', 'fnlwgt','education','education-num','marital-status','occupation',
                'relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country', 'Income']

# %%
data = pd.DataFrame(data.values, columns=column_names)

# %%
data.head()
# Out:
#   age          workclass  fnlwgt   education education-num  \
# 0  50   Self-emp-not-inc   83311   Bachelors            13
# 1  38            Private  215646     HS-grad             9
# 2  53            Private  234721        11th             7
# 3  28            Private  338409   Bachelors            13
# 4  37            Private  284582     Masters            14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#   capital-gain capital-loss hours-per-week  native-country  Income
# 0            0            0             13   United-States   <=50K
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
data.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21647
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# Income                2
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
# age               32560 non-null object
# workclass         32560 non-null object
# fnlwgt            32560 non-null object
# education         32560 non-null object
# education-num     32560 non-null object
# marital-status    32560 non-null object
# occupation        32560 non-null object
# relationship      32560 non-null object
# race              32560 non-null object
# sex               32560 non-null object
# capital-gain      32560 non-null object
# capital-loss      32560 non-null object
# hours-per-week    32560 non-null object
# native-country    32560 non-null object
# Income            32560 non-null object
# dtypes: object(15)
# memory usage: 3.7+ MB

# %%
data = data.infer_objects()

# %%
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
# age               32560 non-null int64
# workclass         32560 non-null object
# fnlwgt            32560 non-null int64
# education         32560 non-null object
# education-num     32560 non-null int64
# marital-status    32560 non-null object
# occupation        32560 non-null object
# relationship      32560 non-null object
# race              32560 non-null object
# sex               32560 non-null object
# capital-gain      32560 non-null int64
# capital-loss      32560 non-null int64
# hours-per-week    32560 non-null int64
# native-country    32560 non-null object
# Income            32560 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Use strip to remove white space characters before and after our data
data['Income'] = data['Income'].str.strip()
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Income
# 0             0             0              13   United-States  <=50K
# ...

# %%
# Total number of records
n_records = data.shape[0]

# Number of records where individual's income is more than $50,000
n_greater_50k = data.loc[data['Income'] == '>50K'].shape[0]

# Number of records where individual's income is at most $50,000
n_at_most_50k = data[data['Income'] == '<=50K'].shape[0]

# Percentage of individuals whose income is more than $50,000
greater_percent = (n_greater_50k / n_records) * 100

# Print the results
print("Total number of records: {}".format(n_records))
print("Individuals making more than $50,000: {}".format(n_greater_50k))
print("Individuals making at most $50,000: {}".format(n_at_most_50k))
print("Percentage of individuals making more than $50,000: {:.2f}%".format(greater_percent))
# Out:
# Total number of records: 32560
# Individuals making more than $50,000: 7841
# Individuals making at most $50,000: 24719
# Percentage of individuals making more than $50,000: 24.08%

# %%
# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid", color_codes=True)
sns.factorplot("sex", col='education', data=data, hue='Income', kind="count", col_wrap=4);
# Out:
# C:\Users\SHIVAM SINGH\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Age Histogram 
data.hist(column='age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020696F4CBC8>]],
#       dtype=object)

# %%
data.hist(column='capital-gain')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020696FA4108>]],
#       dtype=object)

# %%
data.hist(column='capital-loss')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020697016BC8>]],
#       dtype=object)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))

data.hist('capital-gain', bins=20, ax=axes[0])
data.hist('capital-loss', bins=20, ax=axes[1])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002069718C4C8>],
#       dtype=object)

# %%
skewed = ['capital-gain', 'capital-loss']
data[skewed] = data[skewed].apply(lambda x: np.log(x+1))

# %%
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Income
# 0           0.0           0.0              13   United-States  <=50K
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))

data.hist('capital-gain', bins=20, ax=axes[0])
data.hist('capital-loss', bins=20, ax=axes[1])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000206972FC2C8>],
#       dtype=object)

# %%
# fnlwgt: final weight. In other words, this is the number of people the census believes the entry represents
data.drop(['fnlwgt'], axis=1, inplace=True)
data.head()
# Out:
#    age          workclass   education  education-num       marital-status  \
# 0   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 1   38            Private     HS-grad              9             Divorced
# 2   53            Private        11th              7   Married-civ-spouse
# 3   28            Private   Bachelors             13   Married-civ-spouse
# 4   37            Private     Masters             14   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0     Exec-managerial         Husband   White     Male           0.0
# 1   Handlers-cleaners   Not-in-family   White     Male           0.0
# 2   Handlers-cleaners         Husband   Black     Male           0.0
# 3      Prof-specialty            Wife   Black   Female           0.0
# 4     Exec-managerial            Wife   White   Female           0.0
#
#    capital-loss  hours-per-week  native-country Income
# ...

# %%
# Check for nulls
data[data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, Income]
# Index: []

# %%
# Find '?' in dataset column occupation
data[data['occupation'] == " ?"]
# Out:
#        age workclass      education  education-num          marital-status  \
# 26      54         ?   Some-college             10      Married-civ-spouse
# 60      32         ?        7th-8th              4   Married-spouse-absent
# 68      25         ?   Some-college             10           Never-married
# 76      67         ?           10th              6      Married-civ-spouse
# 105     17         ?           10th              6           Never-married
# ...    ...       ...            ...            ...                     ...
# 32529   35         ?      Bachelors             13      Married-civ-spouse
# 32530   30         ?      Bachelors             13           Never-married
# 32538   71         ?      Doctorate             16      Married-civ-spouse
# 32540   41         ?        HS-grad              9               Separated
# 32541   72         ?        HS-grad              9      Married-civ-spouse
#
# ...

# %%
data[data['native-country'] == " ?"]
# Out:
#        age          workclass      education  education-num  \
# 13      40            Private      Assoc-voc             11
# 37      31            Private   Some-college             10
# 50      18            Private        HS-grad              9
# 60      32                  ?        7th-8th              4
# 92      30            Private        HS-grad              9
# ...    ...                ...            ...            ...
# 32448   44       Self-emp-inc        Masters             14
# 32468   58       Self-emp-inc      Doctorate             16
# 32491   42   Self-emp-not-inc        HS-grad              9
# 32509   39            Private        HS-grad              9
# 32524   81                  ?      Assoc-voc             11
#
#                marital-status       occupation    relationship  \
# 13         Married-civ-spouse     Craft-repair         Husband
# 37         Married-civ-spouse            Sales         Husband
# ...

# %%
## Drop missing data
#census = census[census['workclass'] != " ?"]
data = data[data['occupation'] != " ?"]
data = data[data['native-country'] != " ?"]

# %%
data.head()
# Out:
#    age          workclass   education  education-num       marital-status  \
# 0   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 1   38            Private     HS-grad              9             Divorced
# 2   53            Private        11th              7   Married-civ-spouse
# 3   28            Private   Bachelors             13   Married-civ-spouse
# 4   37            Private     Masters             14   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0     Exec-managerial         Husband   White     Male           0.0
# 1   Handlers-cleaners   Not-in-family   White     Male           0.0
# 2   Handlers-cleaners         Husband   Black     Male           0.0
# 3      Prof-specialty            Wife   Black   Female           0.0
# 4     Exec-managerial            Wife   White   Female           0.0
#
#    capital-loss  hours-per-week  native-country Income
# ...

# %% [markdown]
# # Preparing Our Data For Modelling

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize a scaler, then apply it to the features
scaler = MinMaxScaler() # default=(0, 1)
numerical = ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# Make a copy of original Df
data_minmax_transform = pd.DataFrame(data = data)

# Scale our numerical data
data_minmax_transform[numerical] = scaler.fit_transform(data_minmax_transform[numerical])

# %%
data_minmax_transform.head()
# Out:
#         age          workclass   education  education-num  \
# 0  0.452055   Self-emp-not-inc   Bachelors       0.800000
# 1  0.287671            Private     HS-grad       0.533333
# 2  0.493151            Private        11th       0.400000
# 3  0.150685            Private   Bachelors       0.800000
# 4  0.273973            Private     Masters       0.866667
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Income
# 0           0.0           0.0        0.122449   United-States  <=50K
# ...

# %%
# Get raw income numbers and drop it from our census_minmax_transform dataframe
income_raw = data_minmax_transform['Income']
data_minmax_transform = data_minmax_transform.drop('Income', axis = 1)

# %%
features_final = pd.get_dummies(data_minmax_transform)
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
income = income_raw.apply(lambda x:0 if x == '<=50K' else 1)
income = pd.Series(encoder.fit_transform(income_raw))

encoded = list(features_final.columns)
print("{} total features after one-hot encoding.".format(len(encoded)))
print(encoded)
# Out:
# 103 total features after one-hot encoding.
# ...

# %%
data_minmax_transform.nunique()
# Out:
# age                72
# workclass           7
# education          16
# education-num      16
# marital-status      7
# occupation         14
# relationship        6
# race                5
# sex                 2
# capital-gain      118
# capital-loss       90
# hours-per-week     94
# native-country     41
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_final, income, test_size = 0.2, random_state = 0)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 24128 samples.
# Testing set has 6033 samples.

# %% [markdown]
# # Let's try a Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 84.52%
# [[4270  324]
#  [ 610  829]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      4594
#            1       0.72      0.58      0.64      1439
#
#     accuracy                           0.85      6033
#    macro avg       0.80      0.75      0.77      6033
# weighted avg       0.84      0.85      0.84      6033
# C:\Users\SHIVAM SINGH\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %% [markdown]
# # Let's try a Random tree Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
rf_score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# C:\Users\SHIVAM SINGH\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy 83.79%
# [[4219  375]
#  [ 603  836]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      4594
#            1       0.69      0.58      0.63      1439
#
#     accuracy                           0.84      6033
#    macro avg       0.78      0.75      0.76      6033
# weighted avg       0.83      0.84      0.83      6033

# %% [markdown]
# # Let's try a Decision tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
dec_score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 81.30%
# [[4039  555]
#  [ 573  866]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      4594
#            1       0.61      0.60      0.61      1439
#
#     accuracy                           0.81      6033
#    macro avg       0.74      0.74      0.74      6033
# weighted avg       0.81      0.81      0.81      6033

# %% [markdown]
# # Let's try a AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = AdaBoostClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
ada_score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 85.65%
# [[4313  281]
#  [ 585  854]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      4594
#            1       0.75      0.59      0.66      1439
#
#     accuracy                           0.86      6033
#    macro avg       0.82      0.77      0.79      6033
# weighted avg       0.85      0.86      0.85      6033

# %%
import xgboost
classifier=xgboost.XGBClassifier(max_depth=6, learning_rate=0.01, n_estimators=400)
classifier.fit(X_train, y_train)
XY_pred = classifier.predict(X_test)
classifier.score(X_train, y_train)
acc_xgboost = round(classifier.score(X_train, y_train) * 100, 2)
acc_xgboost
# Out:
# 86.57

# %% [markdown]
# We draw a conclusion that AdaBoost and XGBoost gives us the better result.
